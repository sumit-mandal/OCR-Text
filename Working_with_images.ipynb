# %%
from PIL import Image

im_file = "data/page_01.jpg"

im = Image.open(im_file)

print(im)

im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1522 at 0x27FBFAB5308>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1522 at 0x27FBFAB5308>

# %%
im.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1522 at 0x27FC02AF8C8>

# %%
import os
if not os.path.exists('temp'):
    os.makedirs('temp')
im.save("temp/page_01.jpg")
